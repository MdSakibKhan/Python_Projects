# %%
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt

# %%
img1 = cv2.imread('images/sakib1.png')
plt.imshow(img1[:,:,::-1])
plt.show()

img2 = cv2.imread('images/shahrukh1.jpg')
plt.imshow(img2[:,:,::-1])
plt.show()

# %%
result = DeepFace.verify(img1, img2)

# %%
#Here is our result... 

print ("Similarity Check : " , result['verified'])
# Out:
# Similarity Check :  False

# %%
img1 = cv2.imread('images/sakib1.png')
plt.imshow(img1[:,:,::-1])
plt.show()

img2 = cv2.imread('images/sakib2.jpg')
plt.imshow(img2[:,:,::-1])
plt.show()

# %%
result = DeepFace.verify(img1, img2)

# %%
#Here is our result... 

print ("Similarity Check : " , result['verified'])
# Out:
# Similarity Check :  True

# %%
img1 = cv2.imread('images/sakib1.png')
plt.imshow(img1[:,:,::-1])
plt.show()

img2 = cv2.imread('images/sakib3.png')
plt.imshow(img2[:,:,::-1])
plt.show()

# %%
result = DeepFace.verify(img1, img2)

# %%
#Here is our result... 

print ("Similarity Check : " , result['verified'])
# Out:
# Similarity Check :  True

# %%
img1 = cv2.imread('images/shahrukh1.jpg')
plt.imshow(img1[:,:,::-1])
plt.show()

img2 = cv2.imread('images/sakib3.png')
plt.imshow(img2[:,:,::-1])
plt.show()

# %%
result = DeepFace.verify(img1, img2)

# %%
#Here is our result... 

print ("Similarity Check : " , result['verified'])
# Out:
# Similarity Check :  False
